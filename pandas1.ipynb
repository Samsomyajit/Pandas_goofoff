# %%
#SAM
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(data=my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_list, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_list,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1 = pd.Series([1,2,3,4],index = ['USA', 'Germany','USSR', 'Japan'])
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2 = pd.Series([1,2,5,4],index = ['USA', 'Germany','Italy', 'Japan'])
ser2
# Out:
# USA        1
# Germany    2
# Italy      5
# Japan      4
# dtype: int64

# %%
ser3 = ser1.add(ser2)
ser3
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %%
#dataframe

# %%
df = pd.DataFrame(np.random.randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())
df
# Out:
#           W         X         Y         Z
# A -2.089853  1.462023  0.893414  0.732234
# B -0.573439 -1.268741  0.928057  1.114516
# C  0.972363 -1.106571  1.166649  0.911619
# D -0.197025  0.761015  0.989270 -2.302671
# E  0.278859  0.683328  0.606011  0.866292

# %%
df['W']
# Out:
# A   -2.089853
# B   -0.573439
# C    0.972363
# D   -0.197025
# E    0.278859
# Name: W, dtype: float64

# %%
# Pass a list of column names
df[['W','Z']]
# Out:
#           W         Z
# A -2.089853  0.732234
# B -0.573439  1.114516
# C  0.972363  0.911619
# D -0.197025 -2.302671
# E  0.278859  0.866292

# %%
df.W
# Out:
# A   -2.089853
# B   -0.573439
# C    0.972363
# D   -0.197025
# E    0.278859
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
df['new'] = df['W'] + df['Y']
df
# Out:
#           W         X         Y         Z       new
# A -2.089853  1.462023  0.893414  0.732234 -1.196439
# B -0.573439 -1.268741  0.928057  1.114516  0.354617
# C  0.972363 -1.106571  1.166649  0.911619  2.139012
# D -0.197025  0.761015  0.989270 -2.302671  0.792245
# E  0.278859  0.683328  0.606011  0.866292  0.884870

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z
# A -2.089853  1.462023  0.893414  0.732234
# B -0.573439 -1.268741  0.928057  1.114516
# C  0.972363 -1.106571  1.166649  0.911619
# D -0.197025  0.761015  0.989270 -2.302671
# E  0.278859  0.683328  0.606011  0.866292

# %%
df
# Out:
#           W         X         Y         Z       new
# A  1.240714 -0.591550 -0.759371 -0.114395  0.481343
# B  0.182752  1.456029  0.330776  0.832506  0.513527
# C  0.311751  1.809169  1.406149  1.339352  1.717901
# D  0.103030  1.851621 -0.332683 -0.348043 -0.229653
# E -1.611648 -1.636214  0.179651  1.720389 -1.431997

# %%
df.drop('new',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  1.240714 -0.591550 -0.759371 -0.114395
# B  0.182752  1.456029  0.330776  0.832506
# C  0.311751  1.809169  1.406149  1.339352
# D  0.103030  1.851621 -0.332683 -0.348043
# E -1.611648 -1.636214  0.179651  1.720389

# %%
df.drop('E',axis=0)
# Out:
#           W         X         Y         Z
# A  1.240714 -0.591550 -0.759371 -0.114395
# B  0.182752  1.456029  0.330776  0.832506
# C  0.311751  1.809169  1.406149  1.339352
# D  0.103030  1.851621 -0.332683 -0.348043

# %%
df.loc['A']
# Out:
# W    1.240714
# X   -0.591550
# Y   -0.759371
# Z   -0.114395
# Name: A, dtype: float64

# %%
df.iloc[2]
# Out:
# W    0.311751
# X    1.809169
# Y    1.406149
# Z    1.339352
# Name: C, dtype: float64

# %%
df.iloc[:,2]
# Out:
# A   -0.759371
# B    0.330776
# C    1.406149
# D   -0.332683
# E    0.179651
# Name: Y, dtype: float64

# %%
df.loc['B','Y']
# Out:
# 0.3307756244156209

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A  1.240714 -0.759371
# B  0.182752  0.330776

# %%
df
# Out:
#           W         X         Y         Z
# A  1.240714 -0.591550 -0.759371 -0.114395
# B  0.182752  1.456029  0.330776  0.832506
# C  0.311751  1.809169  1.406149  1.339352
# D  0.103030  1.851621 -0.332683 -0.348043
# E -1.611648 -1.636214  0.179651  1.720389

# %%
df>0
# Out:
#        W      X      Y      Z
# A   True  False  False  False
# B   True   True   True   True
# C   True   True   True   True
# D   True   True  False  False
# E  False  False   True   True

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A  1.240714       NaN       NaN       NaN
# B  0.182752  1.456029  0.330776  0.832506
# C  0.311751  1.809169  1.406149  1.339352
# D  0.103030  1.851621       NaN       NaN
# E       NaN       NaN  0.179651  1.720389

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# A  1.240714 -0.591550 -0.759371 -0.114395
# B  0.182752  1.456029  0.330776  0.832506
# C  0.311751  1.809169  1.406149  1.339352
# D  0.103030  1.851621 -0.332683 -0.348043

# %%
df[df['W']>0]['Y']
# Out:
# A   -0.759371
# B    0.330776
# C    1.406149
# D   -0.332683
# Name: Y, dtype: float64

# %%
df[df['W']>0][['Y','X']]
# Out:
#           Y         X
# A -0.759371 -0.591550
# B  0.330776  1.456029
# C  1.406149  1.809169
# D -0.332683  1.851621

# %%
df[(df['W']>0) & (df['Y'] > 1)]
# Out:
#           W         X         Y         Z
# C  0.311751  1.809169  1.406149  1.339352

# %%
df
# Out:
#           W         X         Y         Z
# A  1.240714 -0.591550 -0.759371 -0.114395
# B  0.182752  1.456029  0.330776  0.832506
# C  0.311751  1.809169  1.406149  1.339352
# D  0.103030  1.851621 -0.332683 -0.348043
# E -1.611648 -1.636214  0.179651  1.720389

# %%
# Reset to default 0,1...n index
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  1.240714 -0.591550 -0.759371 -0.114395
# 1     B  0.182752  1.456029  0.330776  0.832506
# 2     C  0.311751  1.809169  1.406149  1.339352
# 3     D  0.103030  1.851621 -0.332683 -0.348043
# 4     E -1.611648 -1.636214  0.179651  1.720389

# %%
newind = 'CA NY WY OR CO'.split()

# %%
df['States'] = newind
df
# Out:
#           W         X         Y         Z States
# A  1.240714 -0.591550 -0.759371 -0.114395     CA
# B  0.182752  1.456029  0.330776  0.832506     NY
# C  0.311751  1.809169  1.406149  1.339352     WY
# D  0.103030  1.851621 -0.332683 -0.348043     OR
# E -1.611648 -1.636214  0.179651  1.720389     CO

# %%
df.set_index('States')
# Out:
#                W         X         Y         Z
# States
# CA      1.240714 -0.591550 -0.759371 -0.114395
# NY      0.182752  1.456029  0.330776  0.832506
# WY      0.311751  1.809169  1.406149  1.339352
# OR      0.103030  1.851621 -0.332683 -0.348043
# CO     -1.611648 -1.636214  0.179651  1.720389

# %%
df
# Out:
#           W         X         Y         Z States
# A  1.240714 -0.591550 -0.759371 -0.114395     CA
# B  0.182752  1.456029  0.330776  0.832506     NY
# C  0.311751  1.809169  1.406149  1.339352     WY
# D  0.103030  1.851621 -0.332683 -0.348043     OR
# E -1.611648 -1.636214  0.179651  1.720389     CO

# %%
df.set_index('States',inplace=True)

# %%
df
# Out:
#                W         X         Y         Z
# States
# CA      1.240714 -0.591550 -0.759371 -0.114395
# NY      0.182752  1.456029  0.330776  0.832506
# WY      0.311751  1.809169  1.406149  1.339352
# OR      0.103030  1.851621 -0.332683 -0.348043
# CO     -1.611648 -1.636214  0.179651  1.720389

# %%
# Index Levels
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index
# Out:
# MultiIndex(levels=[['G1', 'G2'], [1, 2, 3]],
#            codes=[[0, 0, 0, 1, 1, 1], [0, 1, 2, 0, 1, 2]])

# %%
df = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['A','B'])
df
# Out:
#              A         B
# G1 1  0.787665  0.960831
#    2 -0.529593 -1.435909
#    3  1.203602 -0.388750
# G2 1 -0.543699  0.136306
#    2  0.396545 -1.296073
#    3 -0.840594 -2.317968

# %%
df.loc['G1']
# Out:
#           A         B
# 1  0.787665  0.960831
# 2 -0.529593 -1.435909
# 3  1.203602 -0.388750

# %%
df.loc['G1'].loc[1]
# Out:
# A    0.787665
# B    0.960831
# Name: 1, dtype: float64

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Group','Num']
df
# Out:
#                   A         B
# Group Num
# G1    1    0.787665  0.960831
#       2   -0.529593 -1.435909
#       3    1.203602 -0.388750
# G2    1   -0.543699  0.136306
#       2    0.396545 -1.296073
#       3   -0.840594 -2.317968

# %%
df.xs('G1')
# Out:
#             A         B
# Num
# 1    0.787665  0.960831
# 2   -0.529593 -1.435909
# 3    1.203602 -0.388750

# %%
df.xs(['G1',1])
# Out:
# A    0.787665
# B    0.960831
# Name: (G1, 1), dtype: float64

# %%
df.xs(1,level='Num')
# Out:
#               A         B
# Group
# G1     0.787665  0.960831
# G2    -0.543699  0.136306

# %%
# missing data

# %%
df = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.fillna(value='Fill')
# Out:
#           W         X         Y         Z       new
# A -2.089853  1.462023  0.893414  0.732234 -1.196439
# B -0.573439 -1.268741  0.928057  1.114516  0.354617
# C  0.972363 -1.106571  1.166649  0.911619  2.139012
# D -0.197025  0.761015  0.989270 -2.302671  0.792245
# E  0.278859  0.683328  0.606011  0.866292  0.884870

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df['A'] = df['A'].fillna(value=df['A'].mean())

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  1.5  NaN  3

# %%
#Groupby

# %%
import pandas as pd
# Create dataframe
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}
data
# Out:
# {'Company': ['GOOG', 'GOOG', 'MSFT', 'MSFT', 'FB', 'FB'],
#  'Person': ['Sam', 'Charlie', 'Amy', 'Vanessa', 'Carl', 'Sarah'],
#  'Sales': [200, 120, 340, 124, 243, 350]}

# %%
df = pd.DataFrame(data)
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
df.groupby('Company')

# %%
by_comp = df.groupby("Company")

# %%
by_comp.mean()
# Out:
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
df.groupby('Company').mean()
# Out:
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
by_comp.std()
# Out:
#               Sales
# Company
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065

# %%
by_comp.min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
by_comp.max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
by_comp.count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOG          2      2
# MSFT          2      2

# %%
by_comp.describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
by_comp.describe().transpose()
# Out:
# Company              FB        GOOG        MSFT
# Sales count    2.000000    2.000000    2.000000
#       mean   296.500000  160.000000  232.000000
#       std     75.660426   56.568542  152.735065
#       min    243.000000  120.000000  124.000000
#       25%    269.750000  140.000000  178.000000
#       50%    296.500000  160.000000  232.000000
#       75%    323.250000  180.000000  286.000000
#       max    350.000000  200.000000  340.000000

# %%
by_comp.describe().transpose()['GOOG']
# Out:
# Sales  count      2.000000
#        mean     160.000000
#        std       56.568542
#        min      120.000000
#        25%      140.000000
#        50%      160.000000
#        75%      180.000000
#        max      200.000000
# Name: GOOG, dtype: float64

# %%
#merging, concatenation

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7]) 
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11'],
                        'E': ['C8', 'C9', 'C10', 'C11'],},
                        index=[8, 9, 10, 11])
df3
# Out:
#       A    B    C    D    E
# 8    A8   B8   C8   D8   C8
# 9    A9   B9   C9   D9   C9
# 10  A10  B10  C10  D10  C10
# 11  A11  B11  C11  D11  C11

# %%
#concatenation
pd.concat([df1,df2,df3],sort=True)
# Out:
#       A    B    C    D    E
# 0    A0   B0   C0   D0  NaN
# 1    A1   B1   C1   D1  NaN
# 2    A2   B2   C2   D2  NaN
# 3    A3   B3   C3   D3  NaN
# 4    A4   B4   C4   D4  NaN
# 5    A5   B5   C5   D5  NaN
# 6    A6   B6   C6   D6  NaN
# 7    A7   B7   C7   D7  NaN
# 8    A8   B8   C8   D8   C8
# 9    A9   B9   C9   D9   C9
# 10  A10  B10  C10  D10  C10
# 11  A11  B11  C11  D11  C11

# %%
pd.concat([df1,df2,df3],sort=True,axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D    E
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8   C8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9   C9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10  C10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11  C11

# %%
#merging

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(left,right,on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(left, right, on=['key1', 'key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
pd.merge(left, right, how='outer', on=['key1', 'key2'])
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K1   A3   B3  NaN  NaN
# 5   K2   K0  NaN  NaN   C3   D3

# %%
pd.merge(left, right, how='right', on=['key1', 'key2'])
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K1   K0   A2   B2  C1  D1
# 2   K1   K0   A2   B2  C2  D2
# 3   K2   K0  NaN  NaN  C3  D3

# %%
pd.merge(left, right,how='left', on=['key1', 'key2'])
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %%
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
#joining

# %%
left.join(right,lsuffix='_left', rsuffix='_right')
# Out:
#   key1_left key2_left   A   B key1_right key2_right   C   D
# 0        K0        K0  A0  B0         K0         K0  C0  D0
# 1        K0        K1  A1  B1         K1         K0  C1  D1
# 2        K1        K0  A2  B2         K1         K0  C2  D2
# 3        K2        K1  A3  B3         K2         K0  C3  D3

# %%
#operations

# %%
import pandas as pd
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head(2)
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def

# %%
df['col2'].unique()
# Out:
# array([444, 555, 666], dtype=int64)

# %%
df['col2'].nunique()
# Out:
# 3

# %%
df['col2'].value_counts()
# Out:
# 444    2
# 555    1
# 666    1
# Name: col2, dtype: int64

# %%
#Select from DataFrame using criteria from multiple columns
newdf = df[(df['col1']>2) & (df['col2']==444)]

# %%
newdf
# Out:
#    col1  col2 col3
# 3     4   444  xyz

# %%
#applying fuctions

# %%
def times2(x):
    return x*2

# %%
df['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df['col1'].sum()
# Out:
# 10

# %%
del df['col1']

# %%
df
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   444  xyz

# %%
df.columns
# Out:
# Index(['col2', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
#sorting ordering

# %%
df
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   444  xyz

# %%
df.sort_values(by='col2') #inplace=False by default
# Out:
#    col2 col3
# 0   444  abc
# 3   444  xyz
# 1   555  def
# 2   666  ghi

# %%
df.isnull()
# Out:
#     col2   col3
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False

# %%
# Drop rows with NaN Values
df.dropna()
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   444  xyz

# %%
df = pd.DataFrame({'col1':[1,2,3,np.nan],
                   'col2':[np.nan,555,666,444],
                   'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz

# %%
df.fillna('FILL')
# Out:
#    col1  col2 col3
# 0     1  FILL  abc
# 1     2   555  def
# 2     3   666  ghi
# 3  FILL   444  xyz

# %%
data = {'A':['foo','foo','foo','bar','bar','bar'],
     'B':['one','one','two','two','one','one'],
       'C':['x','y','x','y','x','y'],
       'D':[1,3,2,5,4,1]}

df = pd.DataFrame(data)
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.pivot_table(values='D',index=['A', 'B'],columns=['C'])
# Out:
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN

# %%
#data input output

# %%
df = pd.read_csv('example.csv')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e8f767b35e7c> in <module>()
# ----> 1 df = pd.read_csv('example.csv')
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df.to_csv('ex',index=False)

# %%
pd.read_excel('Excel_Sample.xlsx')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
d = df[0]
d
# Out:
#                                              Bank Name                City  \
# 0                                 The Enloe State Bank              Cooper
# 1                  Washington Federal Bank for Savings             Chicago
# 2      The Farmers and Merchants State Bank of Argonia             Argonia
# 3                                  Fayette County Bank          Saint Elmo
# 4    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
#